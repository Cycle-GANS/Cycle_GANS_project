# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
from tensorflow.keras.datasets.mnist import load_data
(x_train,y_train), (x_test,y_test) = load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
#plotting first 10 images
import matplotlib.pyplot as pyplot
for i in range(10):
  pyplot.subplot(2, 5, 1 + i)
  pyplot.axis('off')
  pyplot.imshow(x_train[i], cmap='gray_r')
pyplot.show()

# %%
print(x_test.shape)
# Out:
# (10000, 28, 28)

# %%
X_train = x_train.astype('float32')
X_train = (X_train - 127.5)/127.5

X_test = x_test.astype('float32')
X_test = (X_test - 127.5)/127.5

# %%
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], X_train.shape[2], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], X_test.shape[2], 1))

# %%
from keras.optimizers import Adam
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers import Reshape
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Dropout
from keras.layers import Embedding
from keras.layers import Concatenate

# %%
#functional API for discriminator model
def discriminator(in_shape=(28,28,1),n_classes=10):
    #label input
    # each label is represented by a vector of size 50
    in_label=Input(shape=(1,))
    li = Embedding(n_classes, 50)(in_label)
    n_nodes = in_shape[0] * in_shape[1]  #28x28
    li = Dense(n_nodes)(li)
    li = Reshape((in_shape[0], in_shape[1], 1))(li)  #adding additional channel - 28x28x1

    #image input
    in_image = Input(shape=in_shape)
    merge = Concatenate()([in_image, li]) #28x28x2

    #downsampling to 7x7x1
    fe = Conv2D(128, (3,3), strides=(2,2), padding='same')(merge) #14x14x128
    fe= LeakyReLU(alpha=0.2)(fe)
    fe= Conv2D(128,(3,3), strides=(2,2), padding='same')(fe) #7x7x128
    fe= LeakyReLU(alpha=0.2)(fe)
    fe= Flatten()(fe)
    fe= Dropout(0.4)(fe)
    output= Dense(1, activation='sigmoid')(fe) #probability whether the image is real or fake

    #model
    model = Model([in_image, in_label], output)
    opt=Adam(learning_rate=0.0002, beta_1=0.5, beta_2=0.999)
    model.compile(loss='binary_crossentropy', optimizer= opt,metrics=['accuracy'])
    return model

# %%
discriminator=discriminator()
discriminator.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 1)]                  0         []
#
#  embedding (Embedding)       (None, 1, 50)                500       ['input_1[0][0]']
#
#  dense (Dense)               (None, 1, 784)               39984     ['embedding[0][0]']
#
#  input_2 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  reshape (Reshape)           (None, 28, 28, 1)            0         ['dense[0][0]']
#
#  concatenate (Concatenate)   (None, 28, 28, 2)            0         ['input_2[0][0]',
#                                                                      'reshape[0][0]']
#
#  conv2d (Conv2D)             (None, 14, 14, 128)          2432      ['concatenate[0][0]']
#
#  leaky_re_lu (LeakyReLU)     (None, 14, 14, 128)          0         ['conv2d[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 128)            147584    ['leaky_re_lu[0][0]']
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 7, 7, 128)            0         ['conv2d_1[0][0]']
#
#  flatten (Flatten)           (None, 6272)                 0         ['leaky_re_lu_1[0][0]']
#
#  dropout (Dropout)           (None, 6272)                 0         ['flatten[0][0]']
#
#  dense_1 (Dense)             (None, 1)                    6273      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 196773 (768.64 KB)
# Trainable params: 196773 (768.64 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
#functional API for generator model
def generator(latent_dim,n_classes=10):

    #label input
    in_label = Input(shape=(1,))
    li = Embedding(n_classes, 50)(in_label)

    n_nodes = 7 * 7 # to match the dimensions for concatenation later
    li = Dense(n_nodes)(li) #1,49
    li = Reshape((7, 7, 1))(li)

    #image generator input
    in_lat = Input(shape=(latent_dim,)) #100
    n_nodes = 128 * 7 * 7
    gen = Dense(n_nodes)(in_lat)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Reshape((7, 7, 128))(gen)

    #merge image and label
    merge = Concatenate()([gen, li]) #7x7x128

    #upsampling to (28,28,1)
    gen = Conv2DTranspose(128, (2,2), strides=(1,1), padding='same')(merge)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Conv2DTranspose(128, (4,4), strides=(2,2), padding='same')(gen)
    gen = LeakyReLU(alpha=0.2)(gen)
    gen = Conv2DTranspose(128, (4, 4), strides=(2, 2), padding='same')(gen)
    gen = LeakyReLU(alpha=0.2)(gen)

    output=Conv2D(1,(7,7),activation='tanh', padding='same')(gen)
    model=Model([in_lat, in_label], output) #model that takes noise and label as input and generates output_layer
    return model

# %%
latent_dim=100
generator = generator(latent_dim)
generator.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 100)]                0         []
#
#  input_3 (InputLayer)        [(None, 1)]                  0         []
#
#  dense_3 (Dense)             (None, 6272)                 633472    ['input_4[0][0]']
#
#  embedding_1 (Embedding)     (None, 1, 50)                500       ['input_3[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 6272)                 0         ['dense_3[0][0]']
#
#  dense_2 (Dense)             (None, 1, 49)                2499      ['embedding_1[0][0]']
#
#  reshape_2 (Reshape)         (None, 7, 7, 128)            0         ['leaky_re_lu_2[0][0]']
#
#  reshape_1 (Reshape)         (None, 7, 7, 1)              0         ['dense_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 7, 7, 129)            0         ['reshape_2[0][0]',
#  )                                                                   'reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 7, 7, 128)            66176     ['concatenate_1[0][0]']
#  anspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 7, 7, 128)            0         ['conv2d_transpose[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 14, 14, 128)          262272    ['leaky_re_lu_3[0][0]']
#  Transpose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 14, 14, 128)          0         ['conv2d_transpose_1[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 128)          262272    ['leaky_re_lu_4[0][0]']
#  Transpose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 28, 28, 128)          0         ['conv2d_transpose_2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)            6273      ['leaky_re_lu_5[0][0]']
#
# ==================================================================================================
# Total params: 1233464 (4.71 MB)
# Trainable params: 1233464 (4.71 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
def cgan(d_model, g_model, latent_dim, n_classes=10):
    d_model.trainable = False  #Discriminator is trained separately. So set to not trainable.

    gen_noise, gen_label = g_model.input  #Latent vector size and label size
	# get image output from the generator model
    gen_output = g_model.output  #28x28x1

	# generator image output and corresponding input label are inputs to discriminator
    gan_output = d_model([gen_output, gen_label])
	# define gan model as taking noise and label and outputting a classification
    model = Model([gen_noise, gen_label], gan_output)


    model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.0002, beta_1=0.5))
    return model

# %%
cgan=cgan(discriminator, generator, latent_dim)
cgan.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 100)]                0         []
#
#  input_3 (InputLayer)        [(None, 1)]                  0         []
#
#  dense_3 (Dense)             (None, 6272)                 633472    ['input_4[0][0]']
#
#  embedding_1 (Embedding)     (None, 1, 50)                500       ['input_3[0][0]']
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 6272)                 0         ['dense_3[0][0]']
#
#  dense_2 (Dense)             (None, 1, 49)                2499      ['embedding_1[0][0]']
#
#  reshape_2 (Reshape)         (None, 7, 7, 128)            0         ['leaky_re_lu_2[0][0]']
#
#  reshape_1 (Reshape)         (None, 7, 7, 1)              0         ['dense_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 7, 7, 129)            0         ['reshape_2[0][0]',
#  )                                                                   'reshape_1[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 7, 7, 128)            66176     ['concatenate_1[0][0]']
#  anspose)
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 7, 7, 128)            0         ['conv2d_transpose[0][0]']
#
#  conv2d_transpose_1 (Conv2D  (None, 14, 14, 128)          262272    ['leaky_re_lu_3[0][0]']
#  Transpose)
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 14, 14, 128)          0         ['conv2d_transpose_1[0][0]']
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 128)          262272    ['leaky_re_lu_4[0][0]']
#  Transpose)
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 28, 28, 128)          0         ['conv2d_transpose_2[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 1)            6273      ['leaky_re_lu_5[0][0]']
#
#  model (Functional)          (None, 1)                    196773    ['conv2d_2[0][0]',
#                                                                      'input_3[0][0]']
#
# ==================================================================================================
# Total params: 1430237 (5.46 MB)
# Trainable params: 1233464 (4.71 MB)
# Non-trainable params: 196773 (768.64 KB)
# __________________________________________________________________________________________________

# %%
def load_real_samples():
    #load dataset as list of 2 arrays
    return [X_train, y_train]

# %%
def generate_real_samples(dataset, samples):
    #returning a batch of real inputs and outputs to train the GAN
    images, labels = dataset
    ix = np.random.randint(0, images.shape[0], samples)
    X, labels = images[ix], labels[ix]

    y = np.ones((samples, 1))
    return [X, labels], y

# %%
def generate_latent_points(latent_dim, n_samples,n_classes=10):
    #for generator input
    X_input = np.random.randn(latent_dim * n_samples)
    Z_input = X_input.reshape(n_samples, latent_dim)

    labels = np.random.randint(0, n_classes, n_samples)
    return [Z_input, labels]

# %%
def generate_fake_samples(generator, latent_dim, samples):
    #returning fake inputs and outputs
    Z_input, labels_input = generate_latent_points(latent_dim, samples)

    images = generator.predict([Z_input, labels_input])

    y = np.zeros((samples, 1))
    return [images, labels_input], y

# %%
def train(generator_model, discriminator_model, gan_model, dataset, latent_dim, epochs=100, batch_size=128):
    batch_per_epo = int(dataset[0].shape[0]/batch_size) #total/batchsize
    half_batch = int(batch_size/2)
    for i in range(epochs):
        for j in range(batch_per_epo):

            # Train the discriminator on real and fake images, separately (half batch each)
            #get randomly selceted 'real' samples
            [X_real, labels_real], y_real = generate_real_samples(dataset, half_batch)
            discriminator_loss1, _ = discriminator_model.train_on_batch([X_real, labels_real], y_real)
            #generate fake samples
            [X_fake, labels], y_fake = generate_fake_samples(generator_model, latent_dim, half_batch)
            discriminator_loss2, _ = discriminator_model.train_on_batch([X_fake, labels], y_fake)

            #latent points for input to generator
            [z_input, labels_input] = generate_latent_points(latent_dim, batch_size)

            #inverted labels for fake samples
            y_gan = np.ones((batch_size, 1))

            generator_loss = gan_model.train_on_batch([z_input, labels_input], y_gan)
            print(f'Epoch: {i+1}, Batch: {j+1}/{batch_per_epo}, disc_loss_r = {discriminator_loss1}, disc_loss_f = {discriminator_loss2}, generator loss = {generator_loss}')
        generator_model.save('mnist_cGAN.h5')

# %%
dataset = load_real_samples()
train(generator, discriminator,cgan, dataset, latent_dim, epochs=20)
# Out:
# 2/2 [==============================] - 1s 7ms/step
# Epoch: 1, Batch: 1/468, disc_loss_r = 0.6722462177276611, disc_loss_f = 0.6954870223999023, generator loss = 0.691597580909729
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 2/468, disc_loss_r = 0.5783261060714722, disc_loss_f = 0.6992251873016357, generator loss = 0.6873168349266052
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 3/468, disc_loss_r = 0.5094452500343323, disc_loss_f = 0.7075527906417847, generator loss = 0.678913414478302
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 4/468, disc_loss_r = 0.4466334879398346, disc_loss_f = 0.7228995561599731, generator loss = 0.6641451716423035
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 5/468, disc_loss_r = 0.3908306360244751, disc_loss_f = 0.7498793601989746, generator loss = 0.6411844491958618
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 6/468, disc_loss_r = 0.3403393626213074, disc_loss_f = 0.7920436859130859, generator loss = 0.6082302331924438
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 7/468, disc_loss_r = 0.2953246235847473, disc_loss_f = 0.8571090698242188, generator loss = 0.5719541311264038
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 8/468, disc_loss_r = 0.2712815999984741, disc_loss_f = 0.9265320301055908, generator loss = 0.5324270725250244
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 9/468, disc_loss_r = 0.26178765296936035, disc_loss_f = 0.9820458889007568, generator loss = 0.5193139910697937
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 10/468, disc_loss_r = 0.2658495008945465, disc_loss_f = 0.9922195076942444, generator loss = 0.5337124466896057
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 11/468, disc_loss_r = 0.2875676155090332, disc_loss_f = 0.9377081990242004, generator loss = 0.5747227072715759
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 12/468, disc_loss_r = 0.3177039325237274, disc_loss_f = 0.8600133657455444, generator loss = 0.633449912071228
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 13/468, disc_loss_r = 0.35313019156455994, disc_loss_f = 0.7724860906600952, generator loss = 0.6953727006912231
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 14/468, disc_loss_r = 0.34715285897254944, disc_loss_f = 0.695488452911377, generator loss = 0.7768620848655701
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 15/468, disc_loss_r = 0.3748519718647003, disc_loss_f = 0.6332031488418579, generator loss = 0.8530582189559937
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 16/468, disc_loss_r = 0.37638288736343384, disc_loss_f = 0.577928900718689, generator loss = 0.9518803358078003
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 17/468, disc_loss_r = 0.3753255605697632, disc_loss_f = 0.5048398375511169, generator loss = 1.0440289974212646
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 18/468, disc_loss_r = 0.3655073046684265, disc_loss_f = 0.44343188405036926, generator loss = 1.1562438011169434
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 19/468, disc_loss_r = 0.3631979525089264, disc_loss_f = 0.39610496163368225, generator loss = 1.2649128437042236
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 20/468, disc_loss_r = 0.38840967416763306, disc_loss_f = 0.34378761053085327, generator loss = 1.330033540725708
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 21/468, disc_loss_r = 0.3696787357330322, disc_loss_f = 0.3170480728149414, generator loss = 1.44407320022583
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 22/468, disc_loss_r = 0.31873467564582825, disc_loss_f = 0.28796666860580444, generator loss = 1.5104725360870361
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 23/468, disc_loss_r = 0.2532581090927124, disc_loss_f = 0.25346988439559937, generator loss = 1.6160058975219727
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 24/468, disc_loss_r = 0.2786911427974701, disc_loss_f = 0.23293428122997284, generator loss = 1.7558101415634155
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 25/468, disc_loss_r = 0.23990964889526367, disc_loss_f = 0.1946844458580017, generator loss = 1.8511087894439697
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 26/468, disc_loss_r = 0.22069314122200012, disc_loss_f = 0.18314799666404724, generator loss = 1.9596405029296875
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 27/468, disc_loss_r = 0.2319333851337433, disc_loss_f = 0.16302502155303955, generator loss = 2.02166485786438
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 28/468, disc_loss_r = 0.22874382138252258, disc_loss_f = 0.15692192316055298, generator loss = 2.041595220565796
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 29/468, disc_loss_r = 0.20114770531654358, disc_loss_f = 0.14813411235809326, generator loss = 2.1384830474853516
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 30/468, disc_loss_r = 0.26210469007492065, disc_loss_f = 0.1463979333639145, generator loss = 2.131394863128662
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 31/468, disc_loss_r = 0.1450960487127304, disc_loss_f = 0.12869754433631897, generator loss = 2.2246861457824707
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 32/468, disc_loss_r = 0.11597388237714767, disc_loss_f = 0.11855239421129227, generator loss = 2.3434948921203613
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 33/468, disc_loss_r = 0.18998529016971588, disc_loss_f = 0.10848723351955414, generator loss = 2.3833203315734863
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 34/468, disc_loss_r = 0.14538593590259552, disc_loss_f = 0.11061564832925797, generator loss = 2.4564332962036133
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 35/468, disc_loss_r = 0.13399770855903625, disc_loss_f = 0.09899595379829407, generator loss = 2.4599437713623047
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 36/468, disc_loss_r = 0.1389620304107666, disc_loss_f = 0.10159981995820999, generator loss = 2.616696834564209
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 37/468, disc_loss_r = 0.11783001571893692, disc_loss_f = 0.08771377801895142, generator loss = 2.611959934234619
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 38/468, disc_loss_r = 0.11280113458633423, disc_loss_f = 0.08349300175905228, generator loss = 2.598480224609375
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 39/468, disc_loss_r = 0.07083775103092194, disc_loss_f = 0.07915142178535461, generator loss = 2.798117160797119
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 40/468, disc_loss_r = 0.10354168713092804, disc_loss_f = 0.0708359107375145, generator loss = 2.8006253242492676
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 41/468, disc_loss_r = 0.10631298273801804, disc_loss_f = 0.07145069539546967, generator loss = 2.860330581665039
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 42/468, disc_loss_r = 0.08263975381851196, disc_loss_f = 0.07132995873689651, generator loss = 2.92962384223938
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 43/468, disc_loss_r = 0.07826833426952362, disc_loss_f = 0.06665373593568802, generator loss = 3.009819746017456
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 44/468, disc_loss_r = 0.07060596346855164, disc_loss_f = 0.05533695966005325, generator loss = 3.0405731201171875
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 45/468, disc_loss_r = 0.05604506656527519, disc_loss_f = 0.05447894334793091, generator loss = 3.1212689876556396
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 46/468, disc_loss_r = 0.045782413333654404, disc_loss_f = 0.04574813321232796, generator loss = 3.213408946990967
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 47/468, disc_loss_r = 0.0714634358882904, disc_loss_f = 0.04473300278186798, generator loss = 3.278750419616699
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 48/468, disc_loss_r = 0.07274617999792099, disc_loss_f = 0.046416670083999634, generator loss = 3.2196273803710938
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 49/468, disc_loss_r = 0.04835980758070946, disc_loss_f = 0.041283994913101196, generator loss = 3.242574453353882
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 50/468, disc_loss_r = 0.04395698755979538, disc_loss_f = 0.03778020292520523, generator loss = 3.3528473377227783
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 51/468, disc_loss_r = 0.04618937149643898, disc_loss_f = 0.03680264204740524, generator loss = 3.4201111793518066
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 52/468, disc_loss_r = 0.04729185625910759, disc_loss_f = 0.03705758973956108, generator loss = 3.4326939582824707
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 53/468, disc_loss_r = 0.036302600055933, disc_loss_f = 0.03588773310184479, generator loss = 3.528972864151001
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 54/468, disc_loss_r = 0.046957992017269135, disc_loss_f = 0.03445447236299515, generator loss = 3.5774075984954834
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 55/468, disc_loss_r = 0.05749928578734398, disc_loss_f = 0.03217548877000809, generator loss = 3.5701584815979004
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 56/468, disc_loss_r = 0.028956111520528793, disc_loss_f = 0.03308454900979996, generator loss = 3.639543056488037
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 57/468, disc_loss_r = 0.037400200963020325, disc_loss_f = 0.03167309612035751, generator loss = 3.6988942623138428
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 58/468, disc_loss_r = 0.043581340461969376, disc_loss_f = 0.030968083068728447, generator loss = 3.7817585468292236
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 59/468, disc_loss_r = 0.026758305728435516, disc_loss_f = 0.02779426798224449, generator loss = 3.7643165588378906
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 60/468, disc_loss_r = 0.03496376425027847, disc_loss_f = 0.02578854374587536, generator loss = 3.7844038009643555
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 61/468, disc_loss_r = 0.027177056297659874, disc_loss_f = 0.025692511349916458, generator loss = 3.8834307193756104
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 62/468, disc_loss_r = 0.05588236451148987, disc_loss_f = 0.024498865008354187, generator loss = 3.8257179260253906
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 63/468, disc_loss_r = 0.015251046046614647, disc_loss_f = 0.02381901629269123, generator loss = 3.946225643157959
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 64/468, disc_loss_r = 0.03720898553729057, disc_loss_f = 0.022341959178447723, generator loss = 3.964998960494995
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 65/468, disc_loss_r = 0.019762728363275528, disc_loss_f = 0.02170839160680771, generator loss = 3.989413022994995
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 66/468, disc_loss_r = 0.027005959302186966, disc_loss_f = 0.020359918475151062, generator loss = 4.022098064422607
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 67/468, disc_loss_r = 0.024860940873622894, disc_loss_f = 0.022766362875699997, generator loss = 4.043251991271973
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 68/468, disc_loss_r = 0.027922581881284714, disc_loss_f = 0.021268602460622787, generator loss = 4.139730453491211
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 69/468, disc_loss_r = 0.025124691426753998, disc_loss_f = 0.020351592451334, generator loss = 4.1084418296813965
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 70/468, disc_loss_r = 0.013372985646128654, disc_loss_f = 0.019691674038767815, generator loss = 4.149689674377441
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 71/468, disc_loss_r = 0.054137807339429855, disc_loss_f = 0.01918179541826248, generator loss = 4.1452555656433105
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 72/468, disc_loss_r = 0.020620208233594894, disc_loss_f = 0.019535256549715996, generator loss = 4.1555495262146
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 73/468, disc_loss_r = 0.024403415620326996, disc_loss_f = 0.015850797295570374, generator loss = 4.214818000793457
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 74/468, disc_loss_r = 0.032688602805137634, disc_loss_f = 0.018267886713147163, generator loss = 4.090388774871826
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 75/468, disc_loss_r = 0.01618865504860878, disc_loss_f = 0.017682764679193497, generator loss = 4.265168190002441
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 76/468, disc_loss_r = 0.024494409561157227, disc_loss_f = 0.016427896916866302, generator loss = 4.177000522613525
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 77/468, disc_loss_r = 0.027419012039899826, disc_loss_f = 0.017715036869049072, generator loss = 4.2565484046936035
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 78/468, disc_loss_r = 0.017874756827950478, disc_loss_f = 0.016163889318704605, generator loss = 4.248833179473877
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 79/468, disc_loss_r = 0.023075241595506668, disc_loss_f = 0.018232740461826324, generator loss = 4.276595592498779
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 80/468, disc_loss_r = 0.03213266283273697, disc_loss_f = 0.018061254173517227, generator loss = 4.253305435180664
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 81/468, disc_loss_r = 0.02694125846028328, disc_loss_f = 0.018028927966952324, generator loss = 4.267239093780518
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 82/468, disc_loss_r = 0.01880059204995632, disc_loss_f = 0.017182178795337677, generator loss = 4.2510600090026855
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 83/468, disc_loss_r = 0.017383623868227005, disc_loss_f = 0.014404283836483955, generator loss = 4.406377792358398
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 84/468, disc_loss_r = 0.0031944229267537594, disc_loss_f = 0.013929331675171852, generator loss = 4.456711292266846
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 85/468, disc_loss_r = 0.02792871557176113, disc_loss_f = 0.01413501612842083, generator loss = 4.456400394439697
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 86/468, disc_loss_r = 0.009841974824666977, disc_loss_f = 0.013394867070019245, generator loss = 4.530525207519531
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 87/468, disc_loss_r = 0.017605923116207123, disc_loss_f = 0.012095987796783447, generator loss = 4.588603973388672
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 88/468, disc_loss_r = 0.015666967257857323, disc_loss_f = 0.013145542703568935, generator loss = 4.566515922546387
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 89/468, disc_loss_r = 0.016550317406654358, disc_loss_f = 0.012131085619330406, generator loss = 4.574203014373779
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 90/468, disc_loss_r = 0.0038300941232591867, disc_loss_f = 0.011390896514058113, generator loss = 4.717414855957031
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 91/468, disc_loss_r = 0.007340787909924984, disc_loss_f = 0.01037836354225874, generator loss = 4.773236274719238
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 92/468, disc_loss_r = 0.007935330271720886, disc_loss_f = 0.009099737741053104, generator loss = 4.853071212768555
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 93/468, disc_loss_r = 0.014817323535680771, disc_loss_f = 0.010212704539299011, generator loss = 4.740242004394531
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 94/468, disc_loss_r = 0.018133584409952164, disc_loss_f = 0.010819444432854652, generator loss = 4.830392837524414
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 95/468, disc_loss_r = 0.008425063453614712, disc_loss_f = 0.009704242460429668, generator loss = 4.815752029418945
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 96/468, disc_loss_r = 0.01884150132536888, disc_loss_f = 0.01084541529417038, generator loss = 4.781753063201904
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 97/468, disc_loss_r = 0.005007709376513958, disc_loss_f = 0.00920688733458519, generator loss = 4.953633785247803
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 98/468, disc_loss_r = 0.020042845979332924, disc_loss_f = 0.009456956759095192, generator loss = 4.939984321594238
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 99/468, disc_loss_r = 0.019308341667056084, disc_loss_f = 0.01086912676692009, generator loss = 4.755683898925781
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 100/468, disc_loss_r = 0.004239891655743122, disc_loss_f = 0.010956902988255024, generator loss = 4.885285377502441
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 101/468, disc_loss_r = 0.028322461992502213, disc_loss_f = 0.00939866155385971, generator loss = 4.808825969696045
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 102/468, disc_loss_r = 0.010817816480994225, disc_loss_f = 0.009524858556687832, generator loss = 4.809432029724121
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 103/468, disc_loss_r = 0.005538926925510168, disc_loss_f = 0.008582468144595623, generator loss = 4.8722944259643555
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 104/468, disc_loss_r = 0.009580852463841438, disc_loss_f = 0.009158343076705933, generator loss = 4.985286712646484
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 105/468, disc_loss_r = 0.01678641326725483, disc_loss_f = 0.008198387920856476, generator loss = 4.85871696472168
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 106/468, disc_loss_r = 0.0023030750453472137, disc_loss_f = 0.008115513250231743, generator loss = 5.0201520919799805
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 107/468, disc_loss_r = 0.006149696186184883, disc_loss_f = 0.007001842372119427, generator loss = 5.160416603088379
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 108/468, disc_loss_r = 0.013626222498714924, disc_loss_f = 0.007637265603989363, generator loss = 5.08062744140625
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 109/468, disc_loss_r = 0.004919626750051975, disc_loss_f = 0.006627663038671017, generator loss = 5.128592491149902
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 110/468, disc_loss_r = 0.010055608116090298, disc_loss_f = 0.007520476821810007, generator loss = 5.076481342315674
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 111/468, disc_loss_r = 0.024821527302265167, disc_loss_f = 0.00795731507241726, generator loss = 4.957359790802002
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 112/468, disc_loss_r = 0.0037960121408104897, disc_loss_f = 0.009719191119074821, generator loss = 5.028884410858154
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 113/468, disc_loss_r = 0.0033004474826157093, disc_loss_f = 0.006901504471898079, generator loss = 5.158656120300293
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 114/468, disc_loss_r = 0.003643159754574299, disc_loss_f = 0.006169225089251995, generator loss = 5.238842964172363
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 115/468, disc_loss_r = 0.002436303300783038, disc_loss_f = 0.00546583067625761, generator loss = 5.379384994506836
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 116/468, disc_loss_r = 0.01101686805486679, disc_loss_f = 0.006050950847566128, generator loss = 5.294255256652832
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 117/468, disc_loss_r = 0.01915447972714901, disc_loss_f = 0.00750199519097805, generator loss = 5.225708484649658
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 118/468, disc_loss_r = 0.044838763773441315, disc_loss_f = 0.011926151812076569, generator loss = 4.674538612365723
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 119/468, disc_loss_r = 0.002673666924238205, disc_loss_f = 0.010124750435352325, generator loss = 4.954282760620117
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 120/468, disc_loss_r = 0.0035252179950475693, disc_loss_f = 0.00786878727376461, generator loss = 5.213665008544922
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 121/468, disc_loss_r = 0.0033051958307623863, disc_loss_f = 0.006651448085904121, generator loss = 5.27915620803833
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 122/468, disc_loss_r = 0.003992331679910421, disc_loss_f = 0.0057236747816205025, generator loss = 5.3650078773498535
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 123/468, disc_loss_r = 0.0014775505987927318, disc_loss_f = 0.005159835331141949, generator loss = 5.508420944213867
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 124/468, disc_loss_r = 0.004987133666872978, disc_loss_f = 0.004792704712599516, generator loss = 5.356163024902344
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 1, Batch: 125/468, disc_loss_r = 0.003833896480500698, disc_loss_f = 0.0047606853768229485, generator loss = 5.490321159362793
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 126/468, disc_loss_r = 0.0019181114621460438, disc_loss_f = 0.004984520375728607, generator loss = 5.635019302368164
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 127/468, disc_loss_r = 0.007213102653622627, disc_loss_f = 0.004336388781666756, generator loss = 5.552468299865723
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 128/468, disc_loss_r = 0.009012220427393913, disc_loss_f = 0.005307355895638466, generator loss = 5.545709609985352
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 129/468, disc_loss_r = 0.007288722321391106, disc_loss_f = 0.004397869110107422, generator loss = 5.542726516723633
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 1, Batch: 130/468, disc_loss_r = 0.006752707064151764, disc_loss_f = 0.005073162727057934, generator loss = 5.47511625289917
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 131/468, disc_loss_r = 0.004621436353772879, disc_loss_f = 0.004996183328330517, generator loss = 5.534573554992676
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 132/468, disc_loss_r = 0.0026726960204541683, disc_loss_f = 0.004754330962896347, generator loss = 5.650559425354004
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 133/468, disc_loss_r = 0.01821288652718067, disc_loss_f = 0.005227447487413883, generator loss = 5.412692546844482
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 134/468, disc_loss_r = 0.002675088122487068, disc_loss_f = 0.005800019018352032, generator loss = 5.542187213897705
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 135/468, disc_loss_r = 0.0038066492415964603, disc_loss_f = 0.004690295085310936, generator loss = 5.587886810302734
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 136/468, disc_loss_r = 0.005344552453607321, disc_loss_f = 0.005374734755605459, generator loss = 5.5827765464782715
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 137/468, disc_loss_r = 0.002792763989418745, disc_loss_f = 0.003952996805310249, generator loss = 5.585359573364258
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 138/468, disc_loss_r = 0.008724354207515717, disc_loss_f = 0.004270039964467287, generator loss = 5.658810615539551
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 139/468, disc_loss_r = 0.008376281708478928, disc_loss_f = 0.004682143218815327, generator loss = 5.456377983093262
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 140/468, disc_loss_r = 0.0028319512493908405, disc_loss_f = 0.004298626445233822, generator loss = 5.474846839904785
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 141/468, disc_loss_r = 0.0032967485021799803, disc_loss_f = 0.004744880832731724, generator loss = 5.617070198059082
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 142/468, disc_loss_r = 0.0015484081814065576, disc_loss_f = 0.0034225396811962128, generator loss = 5.755232810974121
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 143/468, disc_loss_r = 0.0011339876800775528, disc_loss_f = 0.003960253670811653, generator loss = 5.893183708190918
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 144/468, disc_loss_r = 0.005325851030647755, disc_loss_f = 0.0033991888631135225, generator loss = 5.779617786407471
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 145/468, disc_loss_r = 0.0347784087061882, disc_loss_f = 0.0049644154496490955, generator loss = 5.592495918273926
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 146/468, disc_loss_r = 0.006949916947633028, disc_loss_f = 0.005904803052544594, generator loss = 5.557842254638672
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 147/468, disc_loss_r = 0.003920279443264008, disc_loss_f = 0.004314525052905083, generator loss = 5.625853538513184
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 148/468, disc_loss_r = 0.0020678858272731304, disc_loss_f = 0.004296293016523123, generator loss = 5.717477798461914
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 149/468, disc_loss_r = 0.002256214153021574, disc_loss_f = 0.0035332245752215385, generator loss = 5.6858110427856445
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 150/468, disc_loss_r = 0.00572627130895853, disc_loss_f = 0.003431665012612939, generator loss = 5.780130863189697
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 151/468, disc_loss_r = 0.020256077870726585, disc_loss_f = 0.004294110462069511, generator loss = 5.5833282470703125
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 152/468, disc_loss_r = 0.005525021348148584, disc_loss_f = 0.0054094684310257435, generator loss = 5.535284519195557
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 153/468, disc_loss_r = 0.0006803383002988994, disc_loss_f = 0.0056345583871006966, generator loss = 5.712268829345703
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 154/468, disc_loss_r = 0.0055438922718167305, disc_loss_f = 0.003874333808198571, generator loss = 5.722195625305176
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 155/468, disc_loss_r = 0.002206228207796812, disc_loss_f = 0.0037281508557498455, generator loss = 5.925396919250488
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 156/468, disc_loss_r = 0.0036796831991523504, disc_loss_f = 0.003703630529344082, generator loss = 5.810948371887207
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 157/468, disc_loss_r = 0.0006202065269462764, disc_loss_f = 0.00329972873441875, generator loss = 5.911691665649414
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 158/468, disc_loss_r = 0.0009229618008248508, disc_loss_f = 0.002892115619033575, generator loss = 5.969351768493652
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 159/468, disc_loss_r = 0.005451308097690344, disc_loss_f = 0.003058472415432334, generator loss = 5.921635150909424
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 160/468, disc_loss_r = 0.04153763875365257, disc_loss_f = 0.004587535746395588, generator loss = 5.4759931564331055
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 161/468, disc_loss_r = 0.002108402783051133, disc_loss_f = 0.005447668023407459, generator loss = 5.58072566986084
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 162/468, disc_loss_r = 0.012702067382633686, disc_loss_f = 0.006363064981997013, generator loss = 5.397777557373047
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 163/468, disc_loss_r = 0.0027841823175549507, disc_loss_f = 0.005857127718627453, generator loss = 5.626847267150879
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 164/468, disc_loss_r = 0.002784912707284093, disc_loss_f = 0.004185616038739681, generator loss = 5.765665054321289
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 165/468, disc_loss_r = 0.0007678557303734124, disc_loss_f = 0.0033024712465703487, generator loss = 5.806954383850098
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 166/468, disc_loss_r = 0.0019100515637546778, disc_loss_f = 0.0034385870676487684, generator loss = 6.041297912597656
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 167/468, disc_loss_r = 0.0005607164930552244, disc_loss_f = 0.003142690286040306, generator loss = 6.054208755493164
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 168/468, disc_loss_r = 0.0025392319075763226, disc_loss_f = 0.0034062396734952927, generator loss = 6.07547664642334
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 169/468, disc_loss_r = 0.004762019030749798, disc_loss_f = 0.0028423487674444914, generator loss = 6.040332794189453
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 170/468, disc_loss_r = 0.0009130838443525136, disc_loss_f = 0.0027183545753359795, generator loss = 6.060758113861084
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 171/468, disc_loss_r = 0.0013156610075384378, disc_loss_f = 0.002305449917912483, generator loss = 6.223426342010498
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 172/468, disc_loss_r = 0.010987279005348682, disc_loss_f = 0.002933664247393608, generator loss = 6.067013263702393
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 173/468, disc_loss_r = 0.0067945802584290504, disc_loss_f = 0.0027650538831949234, generator loss = 5.920711040496826
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 174/468, disc_loss_r = 0.0015093213878571987, disc_loss_f = 0.003502066945657134, generator loss = 5.897482872009277
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 175/468, disc_loss_r = 0.0033521668519824743, disc_loss_f = 0.0031257548835128546, generator loss = 5.880073547363281
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 176/468, disc_loss_r = 0.0013811932876706123, disc_loss_f = 0.0033908411860466003, generator loss = 6.019148349761963
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 177/468, disc_loss_r = 0.005919593386352062, disc_loss_f = 0.002855543512851, generator loss = 6.035271167755127
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 178/468, disc_loss_r = 0.0006660578073933721, disc_loss_f = 0.0030826469883322716, generator loss = 6.089879035949707
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 179/468, disc_loss_r = 0.013819463551044464, disc_loss_f = 0.003649141639471054, generator loss = 5.866796970367432
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 180/468, disc_loss_r = 0.0017348728142678738, disc_loss_f = 0.0037662764079868793, generator loss = 5.860724449157715
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 181/468, disc_loss_r = 0.0006801746203564107, disc_loss_f = 0.002997979521751404, generator loss = 5.920928955078125
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 182/468, disc_loss_r = 0.00019764828903134912, disc_loss_f = 0.0026884088292717934, generator loss = 6.1111931800842285
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 183/468, disc_loss_r = 0.004474800080060959, disc_loss_f = 0.0025972130242735147, generator loss = 6.149547100067139
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 184/468, disc_loss_r = 0.001254021073691547, disc_loss_f = 0.0025282674469053745, generator loss = 6.2234086990356445
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 185/468, disc_loss_r = 0.0036667082458734512, disc_loss_f = 0.0024438295513391495, generator loss = 6.074296951293945
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 186/468, disc_loss_r = 0.0006720599485561252, disc_loss_f = 0.0027915923856198788, generator loss = 6.195077896118164
# 2/2 [==============================] - 0s 12ms/step
# Epoch: 1, Batch: 187/468, disc_loss_r = 0.0006334234494715929, disc_loss_f = 0.0026386850513517857, generator loss = 6.368072032928467
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 188/468, disc_loss_r = 0.0020523089915513992, disc_loss_f = 0.002003374509513378, generator loss = 6.434401512145996
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 1, Batch: 189/468, disc_loss_r = 0.00033750865259207785, disc_loss_f = 0.0020231492817401886, generator loss = 6.381856441497803
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 190/468, disc_loss_r = 0.0020020969677716494, disc_loss_f = 0.0017536557279527187, generator loss = 6.398409843444824
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 191/468, disc_loss_r = 0.002436967333778739, disc_loss_f = 0.0018326372373849154, generator loss = 6.4586687088012695
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 192/468, disc_loss_r = 0.004715973976999521, disc_loss_f = 0.0024498531129211187, generator loss = 6.367067337036133
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 193/468, disc_loss_r = 0.0026030889712274075, disc_loss_f = 0.0019868100062012672, generator loss = 6.308693885803223
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 194/468, disc_loss_r = 0.000433803943451494, disc_loss_f = 0.002217204077169299, generator loss = 6.275421142578125
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 195/468, disc_loss_r = 0.011882057413458824, disc_loss_f = 0.002712483983486891, generator loss = 6.26832389831543
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 1, Batch: 196/468, disc_loss_r = 0.00356182805262506, disc_loss_f = 0.003021461656317115, generator loss = 6.072641372680664
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 197/468, disc_loss_r = 0.00036299473140388727, disc_loss_f = 0.003009207546710968, generator loss = 6.22832727432251
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 198/468, disc_loss_r = 0.0011461409740149975, disc_loss_f = 0.0018734970362856984, generator loss = 6.511029243469238
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 199/468, disc_loss_r = 0.003762252628803253, disc_loss_f = 0.002145863138139248, generator loss = 6.426016807556152
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 200/468, disc_loss_r = 0.00023853391758166254, disc_loss_f = 0.0022910628467798233, generator loss = 6.492635250091553
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 201/468, disc_loss_r = 0.0001965392439160496, disc_loss_f = 0.0019242940470576286, generator loss = 6.5845818519592285
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 202/468, disc_loss_r = 0.00016545385005883873, disc_loss_f = 0.001750489347614348, generator loss = 6.588704586029053
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 203/468, disc_loss_r = 0.0006960025057196617, disc_loss_f = 0.0015950030647218227, generator loss = 6.618587970733643
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 204/468, disc_loss_r = 0.004384312313050032, disc_loss_f = 0.0017352290451526642, generator loss = 6.625480651855469
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 205/468, disc_loss_r = 0.012683356180787086, disc_loss_f = 0.002191548701375723, generator loss = 6.19901180267334
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 206/468, disc_loss_r = 0.0010304186725988984, disc_loss_f = 0.0021089757792651653, generator loss = 6.328743934631348
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 207/468, disc_loss_r = 0.0033680724445730448, disc_loss_f = 0.002842707559466362, generator loss = 6.2847795486450195
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 208/468, disc_loss_r = 0.0025671350304037333, disc_loss_f = 0.0026801484636962414, generator loss = 6.295253753662109
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 1, Batch: 209/468, disc_loss_r = 0.0023206514306366444, disc_loss_f = 0.002209012396633625, generator loss = 6.35282039642334
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 210/468, disc_loss_r = 0.008807187899947166, disc_loss_f = 0.0026606025639921427, generator loss = 6.147705554962158
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 211/468, disc_loss_r = 0.0011662290198728442, disc_loss_f = 0.0029729034285992384, generator loss = 6.200774192810059
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 212/468, disc_loss_r = 0.0009681963128969073, disc_loss_f = 0.002463103737682104, generator loss = 6.370174407958984
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 1, Batch: 213/468, disc_loss_r = 0.0025465453509241343, disc_loss_f = 0.002483687363564968, generator loss = 6.441554069519043
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 214/468, disc_loss_r = 0.006151257548481226, disc_loss_f = 0.002807424869388342, generator loss = 6.324551105499268
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 215/468, disc_loss_r = 0.0005253013805486262, disc_loss_f = 0.002189725637435913, generator loss = 6.350019931793213
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 1, Batch: 216/468, disc_loss_r = 0.0016723352018743753, disc_loss_f = 0.002338412217795849, generator loss = 6.4737677574157715
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 217/468, disc_loss_r = 0.0008885810384526849, disc_loss_f = 0.002161665353924036, generator loss = 6.490665912628174
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 218/468, disc_loss_r = 0.0010491739958524704, disc_loss_f = 0.001805316423997283, generator loss = 6.60466194152832
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 219/468, disc_loss_r = 0.00011519825784489512, disc_loss_f = 0.0017810475546866655, generator loss = 6.679173946380615
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 220/468, disc_loss_r = 0.002094459254294634, disc_loss_f = 0.0014504314167425036, generator loss = 6.565677642822266
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 221/468, disc_loss_r = 0.00020826797117479146, disc_loss_f = 0.0013534440658986568, generator loss = 6.732846736907959
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 222/468, disc_loss_r = 0.0010316967964172363, disc_loss_f = 0.0013564270921051502, generator loss = 6.789403438568115
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 223/468, disc_loss_r = 0.00018898439884651452, disc_loss_f = 0.0012708071153610945, generator loss = 6.728796005249023
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 224/468, disc_loss_r = 0.012078496627509594, disc_loss_f = 0.0017279322491958737, generator loss = 6.552231788635254
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 225/468, disc_loss_r = 0.0006153261638246477, disc_loss_f = 0.001968816854059696, generator loss = 6.476691722869873
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 226/468, disc_loss_r = 7.769231160636991e-05, disc_loss_f = 0.001824554754421115, generator loss = 6.515318393707275
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 227/468, disc_loss_r = 0.0009937090799212456, disc_loss_f = 0.0016711519565433264, generator loss = 6.596435546875
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 228/468, disc_loss_r = 0.00019366765627637506, disc_loss_f = 0.001309728599153459, generator loss = 6.782585144042969
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 229/468, disc_loss_r = 0.007159437984228134, disc_loss_f = 0.001693900441750884, generator loss = 6.6036696434021
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 230/468, disc_loss_r = 0.00012251980660948902, disc_loss_f = 0.0014550985069945455, generator loss = 6.679993629455566
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 231/468, disc_loss_r = 0.000229780183872208, disc_loss_f = 0.002168126404285431, generator loss = 6.680720329284668
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 232/468, disc_loss_r = 0.0007541421218775213, disc_loss_f = 0.001539638382382691, generator loss = 6.756706237792969
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 233/468, disc_loss_r = 0.0001780684688128531, disc_loss_f = 0.0014074902283027768, generator loss = 6.818039894104004
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 234/468, disc_loss_r = 0.0003106816438958049, disc_loss_f = 0.001164774876087904, generator loss = 6.9431471824646
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 235/468, disc_loss_r = 0.0015242702793329954, disc_loss_f = 0.0012531697284430265, generator loss = 7.009330749511719
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 236/468, disc_loss_r = 0.00045925003360025585, disc_loss_f = 0.0012355552753433585, generator loss = 6.9496917724609375
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 237/468, disc_loss_r = 0.001353926258161664, disc_loss_f = 0.0012864457676187158, generator loss = 6.96382999420166
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 238/468, disc_loss_r = 0.0005770622519776225, disc_loss_f = 0.0010792731773108244, generator loss = 7.052224636077881
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 239/468, disc_loss_r = 0.0003556155425030738, disc_loss_f = 0.0012545277131721377, generator loss = 7.200427055358887
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 240/468, disc_loss_r = 0.003272748552262783, disc_loss_f = 0.001178312348201871, generator loss = 7.01578426361084
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 241/468, disc_loss_r = 0.0035706975031644106, disc_loss_f = 0.0013175280764698982, generator loss = 6.857473850250244
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 242/468, disc_loss_r = 0.0020588841289281845, disc_loss_f = 0.0014706638175994158, generator loss = 6.826093673706055
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 243/468, disc_loss_r = 0.0035403030924499035, disc_loss_f = 0.0012874994426965714, generator loss = 6.765984535217285
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 244/468, disc_loss_r = 0.0001730016083456576, disc_loss_f = 0.0013881728518754244, generator loss = 6.850672721862793
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 245/468, disc_loss_r = 0.01419463474303484, disc_loss_f = 0.0023574517108500004, generator loss = 6.291881561279297
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 246/468, disc_loss_r = 0.00032502098474651575, disc_loss_f = 0.0023240174632519484, generator loss = 6.395152568817139
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 247/468, disc_loss_r = 0.0010622289264574647, disc_loss_f = 0.0018877449911087751, generator loss = 6.5915141105651855
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 248/468, disc_loss_r = 0.004832651000469923, disc_loss_f = 0.0018867042381316423, generator loss = 6.40545654296875
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 1, Batch: 249/468, disc_loss_r = 0.00012148320820415393, disc_loss_f = 0.0020354390144348145, generator loss = 6.6286420822143555
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 250/468, disc_loss_r = 0.0023090895265340805, disc_loss_f = 0.0017536720260977745, generator loss = 6.5041890144348145
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 251/468, disc_loss_r = 0.007633103057742119, disc_loss_f = 0.0020417540799826384, generator loss = 6.499993324279785
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 252/468, disc_loss_r = 8.817498746793717e-05, disc_loss_f = 0.002058556769043207, generator loss = 6.421020984649658
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 1, Batch: 253/468, disc_loss_r = 0.0013740876456722617, disc_loss_f = 0.0019227677257731557, generator loss = 6.588267803192139
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 254/468, disc_loss_r = 0.003271989058703184, disc_loss_f = 0.0021028942428529263, generator loss = 6.632397651672363
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 255/468, disc_loss_r = 0.0007703837472945452, disc_loss_f = 0.0017066976288333535, generator loss = 6.648128032684326
# 2/2 [==============================] - 0s 5ms/step
# Epoch: 1, Batch: 256/468, disc_loss_r = 0.0006602545618079603, disc_loss_f = 0.0017342917853966355, generator loss = 6.843455791473389
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 1, Batch: 257/468, disc_loss_r = 0.00030731671722605824, disc_loss_f = 0.001316678011789918, generator loss = 6.769709587097168
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 1, Batch: 258/468, disc_loss_r = 1.6922376744332723e-05, disc_loss_f = 0.0012745208805426955, generator loss = 6.94739294052124
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 259/468, disc_loss_r = 0.0008359176572412252, disc_loss_f = 0.0011348568368703127, generator loss = 7.103846073150635
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 1, Batch: 260/468, disc_loss_r = 0.004729826934635639, disc_loss_f = 0.0013544787652790546, generator loss = 6.824343681335449
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 1, Batch: 261/468, disc_loss_r = 0.0012067104689776897, disc_loss_f = 0.0013434240827336907, generator loss = 6.9673614501953125
# 2/2 [==============================] - 0s 6ms/step
# ...
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 382/468, disc_loss_r = 0.6658554077148438, disc_loss_f = 0.6678646206855774, generator loss = 0.7539743185043335
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 383/468, disc_loss_r = 0.6595132946968079, disc_loss_f = 0.7139286398887634, generator loss = 0.7234488129615784
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 384/468, disc_loss_r = 0.6522447466850281, disc_loss_f = 0.6925565004348755, generator loss = 0.7614401578903198
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 385/468, disc_loss_r = 0.6570296883583069, disc_loss_f = 0.6943227052688599, generator loss = 0.7653247714042664
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 386/468, disc_loss_r = 0.6746221780776978, disc_loss_f = 0.6817581057548523, generator loss = 0.7811650037765503
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 387/468, disc_loss_r = 0.6817705631256104, disc_loss_f = 0.6577575206756592, generator loss = 0.7762148976325989
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 388/468, disc_loss_r = 0.652842104434967, disc_loss_f = 0.6826038360595703, generator loss = 0.8467638492584229
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 389/468, disc_loss_r = 0.6907830238342285, disc_loss_f = 0.6585285663604736, generator loss = 0.8315915465354919
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 390/468, disc_loss_r = 0.6668980121612549, disc_loss_f = 0.6180669069290161, generator loss = 0.8140771389007568
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 391/468, disc_loss_r = 0.6989812850952148, disc_loss_f = 0.6795622110366821, generator loss = 0.7872946262359619
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 392/468, disc_loss_r = 0.7003055810928345, disc_loss_f = 0.6940917372703552, generator loss = 0.7561466693878174
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 393/468, disc_loss_r = 0.7125425338745117, disc_loss_f = 0.6798282861709595, generator loss = 0.7662262916564941
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 394/468, disc_loss_r = 0.6573972702026367, disc_loss_f = 0.695846438407898, generator loss = 0.7428246736526489
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 395/468, disc_loss_r = 0.6748969554901123, disc_loss_f = 0.6934276223182678, generator loss = 0.7578265070915222
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 396/468, disc_loss_r = 0.6429060697555542, disc_loss_f = 0.6866782307624817, generator loss = 0.765461266040802
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 397/468, disc_loss_r = 0.6576353311538696, disc_loss_f = 0.7222994565963745, generator loss = 0.7554013729095459
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 398/468, disc_loss_r = 0.6631006002426147, disc_loss_f = 0.6786142587661743, generator loss = 0.7837550640106201
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 20, Batch: 399/468, disc_loss_r = 0.6757844686508179, disc_loss_f = 0.6969221234321594, generator loss = 0.7657188177108765
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 400/468, disc_loss_r = 0.6738231778144836, disc_loss_f = 0.7036620378494263, generator loss = 0.7697435021400452
# 2/2 [==============================] - 0s 12ms/step
# Epoch: 20, Batch: 401/468, disc_loss_r = 0.6907531023025513, disc_loss_f = 0.6404345035552979, generator loss = 0.7588444948196411
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 402/468, disc_loss_r = 0.6736584305763245, disc_loss_f = 0.6542255878448486, generator loss = 0.7619919180870056
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 403/468, disc_loss_r = 0.6893665790557861, disc_loss_f = 0.6563313007354736, generator loss = 0.7885921597480774
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 404/468, disc_loss_r = 0.6835894584655762, disc_loss_f = 0.6667661666870117, generator loss = 0.8012517094612122
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 405/468, disc_loss_r = 0.663064181804657, disc_loss_f = 0.7023171186447144, generator loss = 0.7860113382339478
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 20, Batch: 406/468, disc_loss_r = 0.6859889626502991, disc_loss_f = 0.6554743051528931, generator loss = 0.7794594764709473
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 407/468, disc_loss_r = 0.6634628772735596, disc_loss_f = 0.6647791862487793, generator loss = 0.7669023871421814
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 408/468, disc_loss_r = 0.6894474625587463, disc_loss_f = 0.6699299216270447, generator loss = 0.765884280204773
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 409/468, disc_loss_r = 0.6583251953125, disc_loss_f = 0.6685740351676941, generator loss = 0.7873021960258484
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 410/468, disc_loss_r = 0.6835907101631165, disc_loss_f = 0.6715618968009949, generator loss = 0.7753986120223999
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 411/468, disc_loss_r = 0.669424295425415, disc_loss_f = 0.6634013652801514, generator loss = 0.7581135630607605
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 412/468, disc_loss_r = 0.6540535092353821, disc_loss_f = 0.673737645149231, generator loss = 0.8013537526130676
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 413/468, disc_loss_r = 0.6828523278236389, disc_loss_f = 0.707825779914856, generator loss = 0.7805096507072449
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 414/468, disc_loss_r = 0.6618725657463074, disc_loss_f = 0.6888383626937866, generator loss = 0.7763910889625549
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 415/468, disc_loss_r = 0.6739609241485596, disc_loss_f = 0.6886614561080933, generator loss = 0.7817339897155762
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 416/468, disc_loss_r = 0.6638574004173279, disc_loss_f = 0.6522572040557861, generator loss = 0.7590854167938232
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 417/468, disc_loss_r = 0.6890434622764587, disc_loss_f = 0.6720622777938843, generator loss = 0.789577305316925
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 418/468, disc_loss_r = 0.6708573698997498, disc_loss_f = 0.6845523118972778, generator loss = 0.8161168098449707
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 419/468, disc_loss_r = 0.6802570223808289, disc_loss_f = 0.6374474763870239, generator loss = 0.8401082754135132
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 420/468, disc_loss_r = 0.717900276184082, disc_loss_f = 0.647788405418396, generator loss = 0.8205778002738953
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 421/468, disc_loss_r = 0.662312388420105, disc_loss_f = 0.6557732820510864, generator loss = 0.7995719909667969
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 422/468, disc_loss_r = 0.6926978826522827, disc_loss_f = 0.6900662183761597, generator loss = 0.7737367749214172
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 423/468, disc_loss_r = 0.675388753414154, disc_loss_f = 0.70148104429245, generator loss = 0.775178849697113
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 424/468, disc_loss_r = 0.6370405554771423, disc_loss_f = 0.6443352699279785, generator loss = 0.7735979557037354
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 425/468, disc_loss_r = 0.6687686443328857, disc_loss_f = 0.6551448702812195, generator loss = 0.7714275121688843
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 20, Batch: 426/468, disc_loss_r = 0.6781167984008789, disc_loss_f = 0.6963050961494446, generator loss = 0.7544302344322205
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 427/468, disc_loss_r = 0.6575291156768799, disc_loss_f = 0.698148250579834, generator loss = 0.7429076433181763
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 428/468, disc_loss_r = 0.6427655816078186, disc_loss_f = 0.6945843696594238, generator loss = 0.7576922178268433
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 429/468, disc_loss_r = 0.6518487930297852, disc_loss_f = 0.7277765274047852, generator loss = 0.7443544268608093
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 430/468, disc_loss_r = 0.6712821125984192, disc_loss_f = 0.6678192615509033, generator loss = 0.7792931795120239
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 20, Batch: 431/468, disc_loss_r = 0.694618284702301, disc_loss_f = 0.6262528300285339, generator loss = 0.8548298478126526
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 432/468, disc_loss_r = 0.6921127438545227, disc_loss_f = 0.6296474933624268, generator loss = 0.8622053265571594
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 20, Batch: 433/468, disc_loss_r = 0.6610217094421387, disc_loss_f = 0.6239352226257324, generator loss = 0.8582810759544373
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 434/468, disc_loss_r = 0.6955095529556274, disc_loss_f = 0.6555209755897522, generator loss = 0.7901475429534912
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 435/468, disc_loss_r = 0.7098909020423889, disc_loss_f = 0.677909255027771, generator loss = 0.7546461820602417
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 436/468, disc_loss_r = 0.699229896068573, disc_loss_f = 0.6770409941673279, generator loss = 0.7663648724555969
# 2/2 [==============================] - 0s 13ms/step
# Epoch: 20, Batch: 437/468, disc_loss_r = 0.6380429267883301, disc_loss_f = 0.6746586561203003, generator loss = 0.7899597883224487
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 438/468, disc_loss_r = 0.663198709487915, disc_loss_f = 0.6664583683013916, generator loss = 0.7755144238471985
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 439/468, disc_loss_r = 0.6113049983978271, disc_loss_f = 0.725996196269989, generator loss = 0.7447925806045532
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 440/468, disc_loss_r = 0.5970176458358765, disc_loss_f = 0.7199512720108032, generator loss = 0.7723982930183411
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 441/468, disc_loss_r = 0.6708567142486572, disc_loss_f = 0.7396239042282104, generator loss = 0.778300404548645
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 442/468, disc_loss_r = 0.6633372902870178, disc_loss_f = 0.6681353449821472, generator loss = 0.8052985668182373
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 443/468, disc_loss_r = 0.6765300035476685, disc_loss_f = 0.6204893589019775, generator loss = 0.869151771068573
# 2/2 [==============================] - 0s 9ms/step
# Epoch: 20, Batch: 444/468, disc_loss_r = 0.6950550675392151, disc_loss_f = 0.6076931953430176, generator loss = 0.9121357202529907
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 445/468, disc_loss_r = 0.7426761388778687, disc_loss_f = 0.6147063970565796, generator loss = 0.8618162870407104
# 2/2 [==============================] - 0s 18ms/step
# Epoch: 20, Batch: 446/468, disc_loss_r = 0.6937793493270874, disc_loss_f = 0.6498299241065979, generator loss = 0.7794817090034485
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 447/468, disc_loss_r = 0.7219071388244629, disc_loss_f = 0.7121503353118896, generator loss = 0.7384693026542664
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 448/468, disc_loss_r = 0.6469355821609497, disc_loss_f = 0.7139773368835449, generator loss = 0.7637985944747925
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 449/468, disc_loss_r = 0.6252274513244629, disc_loss_f = 0.6952144503593445, generator loss = 0.7675257921218872
# 2/2 [==============================] - 0s 10ms/step
# Epoch: 20, Batch: 450/468, disc_loss_r = 0.6645783185958862, disc_loss_f = 0.6895817518234253, generator loss = 0.8066412210464478
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 451/468, disc_loss_r = 0.6484404802322388, disc_loss_f = 0.7119701504707336, generator loss = 0.7982653379440308
# 2/2 [==============================] - 0s 11ms/step
# Epoch: 20, Batch: 452/468, disc_loss_r = 0.6558985710144043, disc_loss_f = 0.6638256311416626, generator loss = 0.787915050983429
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 453/468, disc_loss_r = 0.6289109587669373, disc_loss_f = 0.6734374761581421, generator loss = 0.751185953617096
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 454/468, disc_loss_r = 0.6204907298088074, disc_loss_f = 0.7127547860145569, generator loss = 0.7675857543945312
# 2/2 [==============================] - 0s 8ms/step
# Epoch: 20, Batch: 455/468, disc_loss_r = 0.6871047019958496, disc_loss_f = 0.7026122808456421, generator loss = 0.7740824222564697
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 456/468, disc_loss_r = 0.6505950689315796, disc_loss_f = 0.6400295495986938, generator loss = 0.8390029668807983
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 457/468, disc_loss_r = 0.6470285654067993, disc_loss_f = 0.6033616065979004, generator loss = 0.9445708990097046
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 458/468, disc_loss_r = 0.7132840752601624, disc_loss_f = 0.5835880041122437, generator loss = 0.9041669368743896
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 459/468, disc_loss_r = 0.708713173866272, disc_loss_f = 0.6396961212158203, generator loss = 0.8151517510414124
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 460/468, disc_loss_r = 0.7406409978866577, disc_loss_f = 0.7258883118629456, generator loss = 0.7635812759399414
# 2/2 [==============================] - 0s 7ms/step
# Epoch: 20, Batch: 461/468, disc_loss_r = 0.6780408620834351, disc_loss_f = 0.6875543594360352, generator loss = 0.7806572318077087
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 462/468, disc_loss_r = 0.6529867053031921, disc_loss_f = 0.6592414379119873, generator loss = 0.8093011975288391
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 463/468, disc_loss_r = 0.6334996223449707, disc_loss_f = 0.6706464290618896, generator loss = 0.7453722953796387
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 464/468, disc_loss_r = 0.6520914435386658, disc_loss_f = 0.6366314888000488, generator loss = 0.7484976053237915
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 465/468, disc_loss_r = 0.6547691226005554, disc_loss_f = 0.67631995677948, generator loss = 0.7487806081771851
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 466/468, disc_loss_r = 0.6258048415184021, disc_loss_f = 0.7090041637420654, generator loss = 0.7460654973983765
# 2/2 [==============================] - 0s 6ms/step
# Epoch: 20, Batch: 467/468, disc_loss_r = 0.6522928476333618, disc_loss_f = 0.7162843942642212, generator loss = 0.7428203821182251
# 2/2 [==============================] - 0s 10ms/step
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Epoch: 20, Batch: 468/468, disc_loss_r = 0.629111647605896, disc_loss_f = 0.7449827194213867, generator loss = 0.7597205638885498

# %%
# load model
model = tf.keras.models.load_model('mnist_cGAN.h5', compile=False)


# generate points in latent space as input for the generator
latent_points, labels = generate_latent_points(100, 100)
# specify labels - generate 10 sets of labels each gping from 0 to 9
labels = np.asarray([x for _ in range(10) for x in range(10)])
# generate images
X  = model.predict([latent_points, labels])
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
X = (X*255).astype(np.uint8)

import matplotlib.pyplot as plt
def show_plot(examples, n):
	for i in range(n * n):
		plt.subplot(n, n, 1 + i)
		plt.axis('off')
		plt.imshow(examples[i, :, :, :])
	plt.show()

show_plot(X, 10)
# Out:
# 4/4 [==============================] - 1s 86ms/step
